# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('application_data.csv')

# %%
df.columns
# Out:
# Index(['SK_ID_CURR', 'TARGET', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY',
#        ...
#        'FLAG_DOCUMENT_18', 'FLAG_DOCUMENT_19', 'FLAG_DOCUMENT_20',
#        'FLAG_DOCUMENT_21', 'AMT_REQ_CREDIT_BUREAU_HOUR',
#        'AMT_REQ_CREDIT_BUREAU_DAY', 'AMT_REQ_CREDIT_BUREAU_WEEK',
#        'AMT_REQ_CREDIT_BUREAU_MON', 'AMT_REQ_CREDIT_BUREAU_QRT',
#        'AMT_REQ_CREDIT_BUREAU_YEAR'],
#       dtype='object', length=122)

# %%
df.shape
# Out:
# (307511, 122)

# %%
df.isnull().any()
# Out:
# SK_ID_CURR                    False
# TARGET                        False
# NAME_CONTRACT_TYPE            False
# CODE_GENDER                   False
# FLAG_OWN_CAR                  False
#                               ...
# AMT_REQ_CREDIT_BUREAU_DAY      True
# AMT_REQ_CREDIT_BUREAU_WEEK     True
# AMT_REQ_CREDIT_BUREAU_MON      True
# AMT_REQ_CREDIT_BUREAU_QRT      True
# AMT_REQ_CREDIT_BUREAU_YEAR     True
# Length: 122, dtype: bool

# %%
#Filtering the important columns

# %%
ndf=df[["SK_ID_CURR",'NAME_CONTRACT_TYPE','CODE_GENDER','FLAG_OWN_CAR','FLAG_OWN_REALTY','AMT_INCOME_TOTAL','AMT_CREDIT',
        'AMT_ANNUITY','AMT_GOODS_PRICE','NAME_TYPE_SUITE','NAME_INCOME_TYPE','NAME_EDUCATION_TYPE','NAME_FAMILY_STATUS',
       'NAME_HOUSING_TYPE','REGION_POPULATION_RELATIVE','DAYS_BIRTH','OCCUPATION_TYPE','ORGANIZATION_TYPE']].copy()

# %%
ndf.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'OCCUPATION_TYPE',
#        'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
ndf.shape
# Out:
# (307511, 18)

# %%
ndf.isnull().any()
# Out:
# SK_ID_CURR                    False
# NAME_CONTRACT_TYPE            False
# CODE_GENDER                   False
# FLAG_OWN_CAR                  False
# FLAG_OWN_REALTY               False
# AMT_INCOME_TOTAL              False
# AMT_CREDIT                    False
# AMT_ANNUITY                    True
# AMT_GOODS_PRICE                True
# NAME_TYPE_SUITE                True
# NAME_INCOME_TYPE              False
# NAME_EDUCATION_TYPE           False
# NAME_FAMILY_STATUS            False
# NAME_HOUSING_TYPE             False
# REGION_POPULATION_RELATIVE    False
# DAYS_BIRTH                    False
# OCCUPATION_TYPE                True
# ORGANIZATION_TYPE             False
# dtype: bool

# %%
#handling the missing or null values
1.AMT_ANNUITY
2.AMT_GOODS_PRICE
3.NAME_TYPE_SUITE 
4.OCCUPATION_TYPE

# %%
ndf["AMT_ANNUITY"].isnull().sum()
# Out:
# 12

# %%
len(ndf["AMT_ANNUITY"])
# Out:
# 307511

# %%
ndf["AMT_ANNUITY"].isnull().sum()*100/len(ndf["AMT_ANNUITY"])
# Out:
# 0.0039022994299390914

# %%
missing_value=ndf.isnull().sum()*100/len(ndf)

# %%
missing_value
# Out:
# SK_ID_CURR                     0.000000
# NAME_CONTRACT_TYPE             0.000000
# CODE_GENDER                    0.000000
# FLAG_OWN_CAR                   0.000000
# FLAG_OWN_REALTY                0.000000
# AMT_INCOME_TOTAL               0.000000
# AMT_CREDIT                     0.000000
# AMT_ANNUITY                    0.003902
# AMT_GOODS_PRICE                0.090403
# NAME_TYPE_SUITE                0.420148
# NAME_INCOME_TYPE               0.000000
# NAME_EDUCATION_TYPE            0.000000
# NAME_FAMILY_STATUS             0.000000
# NAME_HOUSING_TYPE              0.000000
# REGION_POPULATION_RELATIVE     0.000000
# DAYS_BIRTH                     0.000000
# OCCUPATION_TYPE               31.345545
# ORGANIZATION_TYPE              0.000000
# dtype: float64

# %%
non_null=pd.DataFrame({'missing_values':missing_value})

# %%
non_null
# Out:
#                             missing_values
# SK_ID_CURR                        0.000000
# NAME_CONTRACT_TYPE                0.000000
# CODE_GENDER                       0.000000
# FLAG_OWN_CAR                      0.000000
# FLAG_OWN_REALTY                   0.000000
# AMT_INCOME_TOTAL                  0.000000
# AMT_CREDIT                        0.000000
# AMT_ANNUITY                       0.003902
# AMT_GOODS_PRICE                   0.090403
# NAME_TYPE_SUITE                   0.420148
# NAME_INCOME_TYPE                  0.000000
# NAME_EDUCATION_TYPE               0.000000
# NAME_FAMILY_STATUS                0.000000
# NAME_HOUSING_TYPE                 0.000000
# REGION_POPULATION_RELATIVE        0.000000
# DAYS_BIRTH                        0.000000
# OCCUPATION_TYPE                  31.345545
# ORGANIZATION_TYPE                 0.000000

# %%
non_null.drop(non_null[(non_null['missing_values']==0)].index,inplace=True)

# %%
non_null
# Out:
#                  missing_values
# AMT_ANNUITY            0.003902
# AMT_GOODS_PRICE        0.090403
# NAME_TYPE_SUITE        0.420148
# OCCUPATION_TYPE       31.345545

# %%
#dropping null values column

# %%
ndf.dropna(subset=['AMT_ANNUITY','AMT_GOODS_PRICE','NAME_TYPE_SUITE'],inplace=True)

# %%
ndf.columns
# Out:
# Index(['SK_ID_CURR', 'NAME_CONTRACT_TYPE', 'CODE_GENDER', 'FLAG_OWN_CAR',
#        'FLAG_OWN_REALTY', 'AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_ANNUITY',
#        'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH', 'OCCUPATION_TYPE',
#        'ORGANIZATION_TYPE'],
#       dtype='object')

# %%
ndf["OCCUPATION_TYPE"].mode()[0]
# Out:
# 'Laborers'

# %%
ndf["OCCUPATION_TYPE"].value_counts()
# Out:
# Laborers                 54970
# Sales staff              31957
# Core staff               27426
# Managers                 21275
# Drivers                  18520
# High skill tech staff    11326
# Accountants               9768
# Medicine staff            8504
# Security staff            6694
# Cooking staff             5929
# Cleaning staff            4641
# Private service staff     2637
# Low-skill Laborers        2085
# Waiters/barmen staff      1340
# Secretaries               1300
# Realty agents              748
# HR staff                   559
# IT staff                   522
# Name: OCCUPATION_TYPE, dtype: int64

# %%
ndf["OCCUPATION_TYPE"]=ndf["OCCUPATION_TYPE"].fillna(ndf["OCCUPATION_TYPE"].mode()[0])

# %%
ndf["OCCUPATION_TYPE"].isnull().any()
# Out:
# False

# %%
#no null values available

ndf
# Out:
#         SK_ID_CURR NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0           100002         Cash loans           M            N
# 1           100003         Cash loans           F            N
# 2           100004    Revolving loans           M            Y
# 3           100006         Cash loans           F            N
# 4           100007         Cash loans           M            N
# ...            ...                ...         ...          ...
# 307506      456251         Cash loans           M            N
# 307507      456252         Cash loans           F            N
# 307508      456253         Cash loans           F            N
# 307509      456254         Cash loans           F            N
# 307510      456255         Cash loans           F            N
#
#        FLAG_OWN_REALTY  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0                    Y          202500.0    406597.5      24700.5
# 1                    N          270000.0   1293502.5      35698.5
# ...

# %%
ndf.shape
# Out:
# (306207, 18)

# %%
ndf.isnull().any()
# Out:
# SK_ID_CURR                    False
# NAME_CONTRACT_TYPE            False
# CODE_GENDER                   False
# FLAG_OWN_CAR                  False
# FLAG_OWN_REALTY               False
# AMT_INCOME_TOTAL              False
# AMT_CREDIT                    False
# AMT_ANNUITY                   False
# AMT_GOODS_PRICE               False
# NAME_TYPE_SUITE               False
# NAME_INCOME_TYPE              False
# NAME_EDUCATION_TYPE           False
# NAME_FAMILY_STATUS            False
# NAME_HOUSING_TYPE             False
# REGION_POPULATION_RELATIVE    False
# DAYS_BIRTH                    False
# OCCUPATION_TYPE               False
# ORGANIZATION_TYPE             False
# dtype: bool

# %%
#cleaned the dataset

# %%
#identifying the outliers

# %%
plt.figure(figsize=(10,5))
sns.boxplot(ndf['AMT_ANNUITY'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.boxplot(ndf['AMT_GOODS_PRICE'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,7))
sns.boxplot(ndf['AMT_CREDIT'])
# Out:
# <Axes: >

# %%
plt.figure(figsize=(10,5))
sns.boxplot(ndf['REGION_POPULATION_RELATIVE'])
# Out:
# <Axes: >

# %%
# Removing outliers from the REGION_POPULATION_RELATIVE column 
ndf.drop(ndf[(ndf["REGION_POPULATION_RELATIVE"]>0.05)].index,inplace=True)

# %%
plt.figure(figsize=(10,5))
sns.boxplot(ndf['REGION_POPULATION_RELATIVE'])
# Out:
# <Axes: >

# %%
#data Imbalance
#code_gender -M -male,F-Female,XNA=Unknown
Majority of the applicants are female

# %%
sns.set_theme(style="whitegrid")
sns.countplot(data=ndf,x='CODE_GENDER')
# Out:
# <Axes: xlabel='CODE_GENDER', ylabel='count'>

# %%
#Target variable 
   #(1 - client with payment difficulties: he/she had late payment more than X days on at least one of the first Y installments of the loan in our sample,
#0 - all other cases)

#data Imbalance
--highly data imbalance is present ,

# %%
sns.set_theme(style='whitegrid')
sns.countplot(data=df,x='TARGET')
# Out:
# <Axes: xlabel='TARGET', ylabel='count'>

# %%
plt.figure(figsize=(20,9))
sns.countplot(data=ndf,x='OCCUPATION_TYPE')

#Most of the applicants occupation is Laborers
# Out:
# <Axes: xlabel='OCCUPATION_TYPE', ylabel='count'>

# %%
plt.figure(figsize=(20,9))
sns.countplot(data=ndf,x='NAME_INCOME_TYPE')

#Most of the applicants are from Working sector
# Out:
# <Axes: xlabel='NAME_INCOME_TYPE', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=ndf,x='NAME_EDUCATION_TYPE')

#Most of the applicants has completed secondary education
# Out:
# <Axes: xlabel='NAME_EDUCATION_TYPE', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=ndf,x='NAME_FAMILY_STATUS')

#Most of the applicants are married
# Out:
# <Axes: xlabel='NAME_FAMILY_STATUS', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=ndf,x='NAME_HOUSING_TYPE')

#most of the applicants live in House/Apartment
# Out:
# <Axes: xlabel='NAME_HOUSING_TYPE', ylabel='count'>

# %%
#univariate-Univariate data analysis is a quantitative method in which a variable is examined individually to determine its distribution

# %%
#statistical measure
1.mean
2.median
3.std
4.min
5.25%

# %%
uni=ndf["AMT_ANNUITY"].describe()

# %%
uni
# Out:
# count    297836.000000
# mean      26833.590790
# std       14209.197676
# min        1615.500000
# 25%       16452.000000
# 50%       24718.500000
# 75%       34245.000000
# max      258025.500000
# Name: AMT_ANNUITY, dtype: float64

# %%
def univariate (col):
    print("Mean: ",ndf[col].mean())
    print("Median :",ndf[col].median())
    print(ndf[col].value_counts())
    sns.kdeplot(ndf[col])

# %%
univariate('AMT_INCOME_TOTAL')
# Out:
# Mean:  165648.51311773932
# Median : 144000.0
# 135000.0    35183
# 112500.0    30700
# 157500.0    26071
# 180000.0    23884
# 90000.0     22274
#             ...
# 64584.0         1
# 142897.5        1
# 109170.0        1
# 343890.0        1
# 113062.5        1
# Name: AMT_INCOME_TOTAL, Length: 2418, dtype: int64

# %%
univariate('AMT_GOODS_PRICE')
# Out:
# Mean:  532169.290663318
# Median : 450000.0
# 450000.0     25140
# 225000.0     24624
# 675000.0     24118
# 900000.0     14662
# 270000.0     11188
#              ...
# 447606.0         1
# 2106000.0        1
# 894654.0         1
# 323982.0         1
# 743863.5         1
# Name: AMT_GOODS_PRICE, Length: 979, dtype: int64

# %%
# Segmented Univariated
#Segmented Univariate analysis can be used to find summary of a single data variable in form of segments.
#The dataset variable is divided into subsets and patterns can be observed across the segments.

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='TARGET',hue='CODE_GENDER')

#most of the non-defaulters are Female
# Out:
# <Axes: xlabel='TARGET', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='FLAG_OWN_CAR',hue='TARGET')

#Non-car holders are the most non-defaulters
# Out:
# <Axes: xlabel='FLAG_OWN_CAR', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data=df,x='FLAG_OWN_REALTY',hue='TARGET')

#Most of the non-defaulters has their own property
# Out:
# <Axes: xlabel='FLAG_OWN_REALTY', ylabel='count'>

# %%
sns.countplot(data=df,x='REGION_RATING_CLIENT',hue='TARGET')

#1 rated has non-defaulters
# Out:
# <Axes: xlabel='REGION_RATING_CLIENT', ylabel='count'>

# %%
#Multivariate analysis is defined as: The statistical study 
#of data where multiple measurements are made on each experimental unit and
#where the relationships among multivariate measurements and their structure are important

sns.regplot(data=ndf,x='AMT_CREDIT',y='AMT_ANNUITY')
# Out:
# <Axes: xlabel='AMT_CREDIT', ylabel='AMT_ANNUITY'>

# %%
# Correaltion Matrix


plt.figure(figsize=(20,15))
sns.heatmap(ndf.corr(), annot=True)
plt.show()
# Out:
# C:\Users\Ayesha Anwaruddin\AppData\Local\Temp\ipykernel_33008\2672255535.py:5: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(ndf.corr(), annot=True)

# %%
#TOP Correlations in given Data

/*AMT_CREDIT & AMT_GOODS_PRICE - 0.99

AMT_GOODS_PRICE & AMT_ANNUITY - 0.77

AMT_ANNUITY & AMT_CREDIT - 0.77

AMT_INCOME_TOTAL & AMT_ANNUITY - 0.18

AMT_INCOME_TOTAL & AMT_GOODS_PRICE - 0.15*/

# %%
#Visualization
plt.figure(figsize=(20,5))
sns.countplot(data=ndf,x='NAME_EDUCATION_TYPE',hue='CODE_GENDER')

#Most of the female have completed secondary eduaction
# Out:
# <Axes: xlabel='NAME_EDUCATION_TYPE', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=ndf,x='FLAG_OWN_REALTY',hue='CODE_GENDER')

#Most of the female applicants has the property
# Out:
# <Axes: xlabel='FLAG_OWN_REALTY', ylabel='count'>

# %%
plt.figure(figsize=(20,5))
sns.countplot(data=df,x='NAME_INCOME_TYPE',hue='TARGET')

#Most of the non-defaulters are working
# Out:
# <Axes: xlabel='NAME_INCOME_TYPE', ylabel='count'>
